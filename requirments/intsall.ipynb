# %%
# !pip3 install seaborn streamlit scikit-learn pandas numpy
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Vijay\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
# !pip3 install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ---------------------- --------------- 30.7/52.8 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 52.8/52.8 kB 676.1 kB/s eta 0:00:00
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/119.8 kB ? eta -:--:--
#      -------------------------------------- 119.8/119.8 kB 3.5 MB/s eta 0:00:00
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    - -------------------------------------- 0.2/8.2 MB 5.1 MB/s eta 0:00:02
#    --- ------------------------------------ 0.7/8.2 MB 6.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/8.2 MB 7.2 MB/s eta 0:00:01
#    ------- -------------------------------- 1.5/8.2 MB 9.0 MB/s eta 0:00:01
#    --------- ------------------------------ 2.0/8.2 MB 9.2 MB/s eta 0:00:01
# ...
